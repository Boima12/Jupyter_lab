# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (3.5)
# Requirement already satisfied: matplotlib in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
def kruskal(graph):
    # Step 1: Collect all edges and sort by weight
    edges = []
    for u in graph:
        for v, w in graph[u]:
            if (v, u, w) not in edges:  # avoid duplicate edges
                edges.append((u, v, w))

    edges.sort(key=lambda x: x[2])  # sort by weight

    # Disjoint Set (Union-Find)
    parent = {}
    rank = {}

    def find(node):
        if parent[node] != node:
            parent[node] = find(parent[node])  # path compression
        return parent[node]

    def union(u, v):
        root_u = find(u)
        root_v = find(v)
        if root_u != root_v:
            if rank[root_u] < rank[root_v]:
                parent[root_u] = root_v
            elif rank[root_u] > rank[root_v]:
                parent[root_v] = root_u
            else:
                parent[root_v] = root_u
                rank[root_u] += 1

    # Initialize disjoint sets
    for node in graph.keys():
        parent[node] = node
        rank[node] = 0

    # Step 2: Kruskal's algorithm
    mst = []
    total_weight = 0

    print("Initial sorted edges:", edges)
    print("-------------------------------")

    for i, (u, v, w) in enumerate(edges):
        print(f"Step {i + 1}: Checking edge ({u}, {v}, {w})")
        
        if find(u) != find(v):
            print(f" -> Adding edge ({u}, {v}, {w}) to MST")
            union(u, v)
            mst.append((u, v, w))
            total_weight += w
        else:
            print(f" -> Skipping edge ({u}, {v}, {w}) (would form a cycle)")

        print(f"F: {mst}")
        remaining_edges = edges[i + 1:]
        print(f"E*: {remaining_edges}")
        print("-------------------------------")

    print("Final MST:", mst)
    print("Total weight:", total_weight)
    return mst, total_weight

# %%
import networkx as nx
import matplotlib.pyplot as plt

def visualize_mst(graph, mst):
    G = nx.Graph()

    # Add all nodes and edges
    for u in graph:
        for v, w in graph[u]:
            G.add_edge(u, v, weight=w)

    # Create positions for nodes
    pos = nx.spring_layout(G, seed=42)

    # Draw full graph
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=800, font_size=12)
    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

    # Highlight MST edges
    mst_edges = [(u, v) for u, v, _ in mst]
    nx.draw_networkx_edges(G, pos, edgelist=mst_edges, width=3, edge_color='red')

    plt.title("Minimum Spanning Tree (Kruskal)")
    plt.show()

# %%
graph = {
    'A': [('B', 1), ('F', 3), ('H', 7)],
    'B': [('F', 4), ('A', 1), ('H', 12)],
    'F': [('B', 4), ('A', 3), ('M', 8)],
    'H': [('A', 7), ('B', 12), ('M', 10), ('K', 13)],
    'M': [('F', 8), ('H', 10), ('K', 20)],
    'K': [('M', 20), ('H', 13), ('N', 16)],
    'N': [('K', 16)],
}

mst, total_weight = kruskal(graph)
print("Minimum Spanning Tree:", mst)
print("Total Weight:", total_weight)

visualize_mst(graph, mst)
# Out:
# Initial sorted edges: [('A', 'B', 1), ('A', 'F', 3), ('B', 'F', 4), ('A', 'H', 7), ('F', 'M', 8), ('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 1: Checking edge (A, B, 1)
#  -> Adding edge (A, B, 1) to MST
# Current MST: [('A', 'B', 1)]
# Remaining edges: [('A', 'F', 3), ('B', 'F', 4), ('A', 'H', 7), ('F', 'M', 8), ('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 2: Checking edge (A, F, 3)
#  -> Adding edge (A, F, 3) to MST
# Current MST: [('A', 'B', 1), ('A', 'F', 3)]
# Remaining edges: [('B', 'F', 4), ('A', 'H', 7), ('F', 'M', 8), ('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 3: Checking edge (B, F, 4)
#  -> Skipping edge (B, F, 4) (would form a cycle)
# Current MST: [('A', 'B', 1), ('A', 'F', 3)]
# Remaining edges: [('A', 'H', 7), ('F', 'M', 8), ('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 4: Checking edge (A, H, 7)
#  -> Adding edge (A, H, 7) to MST
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7)]
# Remaining edges: [('F', 'M', 8), ('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 5: Checking edge (F, M, 8)
#  -> Adding edge (F, M, 8) to MST
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8)]
# Remaining edges: [('H', 'M', 10), ('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 6: Checking edge (H, M, 10)
#  -> Skipping edge (H, M, 10) (would form a cycle)
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8)]
# Remaining edges: [('B', 'H', 12), ('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 7: Checking edge (B, H, 12)
#  -> Skipping edge (B, H, 12) (would form a cycle)
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8)]
# Remaining edges: [('H', 'K', 13), ('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 8: Checking edge (H, K, 13)
#  -> Adding edge (H, K, 13) to MST
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8), ('H', 'K', 13)]
# Remaining edges: [('K', 'N', 16), ('M', 'K', 20)]
# -------------------------------
# Step 9: Checking edge (K, N, 16)
#  -> Adding edge (K, N, 16) to MST
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8), ('H', 'K', 13), ('K', 'N', 16)]
# Remaining edges: [('M', 'K', 20)]
# -------------------------------
# Step 10: Checking edge (M, K, 20)
#  -> Skipping edge (M, K, 20) (would form a cycle)
# Current MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8), ('H', 'K', 13), ('K', 'N', 16)]
# Remaining edges: []
# -------------------------------
# Final MST: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8), ('H', 'K', 13), ('K', 'N', 16)]
# Total weight: 48
# Minimum Spanning Tree: [('A', 'B', 1), ('A', 'F', 3), ('A', 'H', 7), ('F', 'M', 8), ('H', 'K', 13), ('K', 'N', 16)]
# Total Weight: 48
