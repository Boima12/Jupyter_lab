# %% [markdown]
# # A_Star

# %% [markdown]
# Thuận toán A Star:
#
# Là thuật toán tìm kiếm thông minh, tìm kiếm dựa trên công thức:
#
# > <b>F = G + H</b>
#
# trong đó:
# F: là chi phí tính được, thuận toán sẽ dựa trên F nhỏ nhất trong cấc lựa chọn tính ra để quyết định đường đi tiếp theo
# G: Chi phí để đi đường đi đó
# H: Là chi phí ước lượng từ vị trí tiếp theo so với đích đến

# %% [markdown]
# ### Các cách để tính H (Heuristics)

# %% [markdown]
# <b>I. Heuristic chuẩn xác</b>
# - tính giá trị chính xác bằng cách sử dụng chính chi phí đường đi G (nhưng rất tốn thời gian)
#
#
#
# <b>II. Heuristic tương đối dành cho bài toán kiểu ô/vị trí tọa độ</b>
# 1. Manhattan distance
# > H = abs(current_cell.x - goal.x) + abs(current_cell.y - goal.y)
#
# điều kiện: Chỉ khi di chuyển sang 4 hướng trái phải lên xuống.
#
#
#
# 2. Diagonal distance
# > dx = abs(current_cell.x - goal.x)<br>
# > dy = abs(current_cell.y - goal.y)<br>
# > H = D * (dx + dy) + (D2 - 2*D) * min(dx, dy)<br>
# > (D usually = 1, D2 usually = sqrt(2) )<br>
#
# điều kiện: Chỉ khi di chuyển cả 8 hướng.
#
#
#
# 3. Euclidean distance
# > H = sqrt((current_cell.x - goal.x)^2 + (current_cell.y - goal.y)^2)
#
# điều kiện: Sử dụng khi có thể di chuyển tự do.
#
#
#
# <b>III. Heuristic tương đối dành cho bài toán kiểu dạng không gian</b>

# %% [markdown]
# ### Setting up
# install these libraries

# %%
# !pip install networkx
# !pip install matplotlib
# Out:
# Requirement already satisfied: networkx in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (3.5)
# Requirement already satisfied: matplotlib in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\caoho\appdata\roaming\jupyterlab-desktop\jlab_server\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ### Bài toán Người du lịch
#
# tìm cách để đi qua được tất cả các thành phố/nodes/vị trí.

# %%
import heapq
from math import inf
import networkx as nx
import matplotlib.pyplot as plt

# %%
def mst_cost(nodes, graph):
    """Compute MST cost using Prim's algorithm for given nodes."""
    if not nodes:
        return 0
    visited = set()
    total_cost = 0
    start = next(iter(nodes))
    visited.add(start)

    while len(visited) < len(nodes):
        min_edge = inf
        next_node = None
        for u in visited:
            for v, cost in graph[u]:
                if v in nodes and v not in visited and cost < min_edge:
                    min_edge = cost
                    next_node = v
        if next_node:
            visited.add(next_node)
            total_cost += min_edge
        else:
            break
    return total_cost

# %%
def tsp_a_star(graph, start):
    cities = list(graph.keys())
    start_city = start

    # Priority Queue: (f, g, current_city, visited_tuple, path)
    pq = []
    heapq.heappush(pq, (0, 0, start_city, frozenset([start_city]), [start_city]))

    best_cost = inf
    best_path = None
    step = 0

    
    while pq:
        f, g, current, visited, path = heapq.heappop(pq)

        print(f"\n=== Step {step} ===")
        print(f"Expanding Node: {current}")
        print(f"Path so far: {path}")
        print(f"Cost so far (g): {g}, Estimated total cost (f): {f}")
        print(f"Visited: {visited}")
        step += 1

        # Goal: visited all cities and return to start
        if len(visited) == len(cities):
            return_cost = next(cost for v, cost in graph[current] if v == start_city)
            total_cost = g + return_cost
            print(f"Reached goal! Returning to start costs {return_cost}, Total: {total_cost}")
            if total_cost < best_cost:
                best_cost = total_cost
                best_path = path + [start_city]
            continue

        # Generate successors
        unvisited = set(cities) - visited
        print(f"Unvisited cities: {unvisited}")

        for neighbor, cost in graph[current]:
            if neighbor not in visited:
                g_new = g + cost

                # Heuristic calculation:
                nearest_unvisited_from_current = min(
                    (c for c in (cost for v, cost in graph[current] if v in unvisited)), default=0
                )
                mst_for_unvisited = mst_cost(unvisited, graph)
                nearest_to_start = min(
                    (cost for v in unvisited for nv, cost in graph[v] if nv == start_city),
                    default=0
                )

                h_new = nearest_unvisited_from_current + mst_for_unvisited + nearest_to_start
                f_new = g_new + h_new

                print(f"\n  Neighbor: {neighbor}")
                print(f"    Edge cost: {cost}")
                print(f"    g_new: {g_new}")
                print(f"    Heuristic breakdown:")
                print(f"      Nearest from current: {nearest_unvisited_from_current}")
                print(f"      MST for unvisited: {mst_for_unvisited}")
                print(f"      Nearest back to start: {nearest_to_start}")
                print(f"    h_new: {h_new}, f_new: {f_new}")

                new_visited = visited | {neighbor}
                heapq.heappush(pq, (f_new, g_new, neighbor, frozenset(new_visited), path + [neighbor]))

        print(f"Priority queue size: {len(pq)}")
    
    print("\n=== Search Complete ===")
    return best_path, best_cost

# %% [markdown]
# ### Sample 1

# %%
graph = {
    'A': [('B', 2), ('C', 9), ('D', 10), ('E', 3)],
    'B': [('A', 2), ('C', 6), ('D', 4), ('E', 3)],
    'C': [('A', 9), ('B', 6), ('D', 8), ('E', 5)],
    'D': [('A', 10), ('B', 4), ('C', 8), ('E', 1)],
    'E': [('A', 3), ('B', 3), ('C', 5), ('D', 1)],
}

path, cost = tsp_a_star(graph, 'A')
print("Best Path:", path)
print("Minimum Cost:", cost)
# Out:
# === Step 0 ===
# Expanding Node: A
# Path so far: ['A']
# Cost so far (g): 0, Estimated total cost (f): 0
# Visited: frozenset({'A'})
# Unvisited cities: {'C', 'D', 'E', 'B'}
#
#   Neighbor: B
#     Edge cost: 2
#     g_new: 2
#     Heuristic breakdown:
#       Nearest from current: 2
#       MST for unvisited: 9
#       Nearest back to start: 2
#     h_new: 13, f_new: 15
#
#   Neighbor: C
#     Edge cost: 9
#     g_new: 9
#     Heuristic breakdown:
#       Nearest from current: 2
#       MST for unvisited: 9
#       Nearest back to start: 2
#     h_new: 13, f_new: 22
#
#   Neighbor: D
#     Edge cost: 10
#     g_new: 10
#     Heuristic breakdown:
#       Nearest from current: 2
#       MST for unvisited: 9
#       Nearest back to start: 2
#     h_new: 13, f_new: 23
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 3
#     Heuristic breakdown:
#       Nearest from current: 2
#       MST for unvisited: 9
#       Nearest back to start: 2
#     h_new: 13, f_new: 16
# Priority queue size: 4
#
# === Step 1 ===
# Expanding Node: B
# Path so far: ['A', 'B']
# Cost so far (g): 2, Estimated total cost (f): 15
# Visited: frozenset({'A', 'B'})
# Unvisited cities: {'C', 'E', 'D'}
#
#   Neighbor: C
#     Edge cost: 6
#     g_new: 8
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 6
#       Nearest back to start: 3
#     h_new: 12, f_new: 20
#
#   Neighbor: D
#     Edge cost: 4
#     g_new: 6
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 6
#       Nearest back to start: 3
#     h_new: 12, f_new: 18
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 5
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 6
#       Nearest back to start: 3
#     h_new: 12, f_new: 17
# Priority queue size: 6
#
# === Step 2 ===
# Expanding Node: E
# Path so far: ['A', 'E']
# Cost so far (g): 3, Estimated total cost (f): 16
# Visited: frozenset({'A', 'E'})
# Unvisited cities: {'C', 'D', 'B'}
#
#   Neighbor: B
#     Edge cost: 3
#     g_new: 6
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 10
#       Nearest back to start: 2
#     h_new: 13, f_new: 19
#
#   Neighbor: C
#     Edge cost: 5
#     g_new: 8
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 10
#       Nearest back to start: 2
#     h_new: 13, f_new: 21
#
#   Neighbor: D
#     Edge cost: 1
#     g_new: 4
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 10
#       Nearest back to start: 2
#     h_new: 13, f_new: 17
# Priority queue size: 8
#
# === Step 3 ===
# Expanding Node: D
# Path so far: ['A', 'E', 'D']
# Cost so far (g): 4, Estimated total cost (f): 17
# Visited: frozenset({'A', 'E', 'D'})
# Unvisited cities: {'C', 'B'}
#
#   Neighbor: B
#     Edge cost: 4
#     g_new: 8
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 6
#       Nearest back to start: 2
#     h_new: 12, f_new: 20
#
#   Neighbor: C
#     Edge cost: 8
#     g_new: 12
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 6
#       Nearest back to start: 2
#     h_new: 12, f_new: 24
# Priority queue size: 9
#
# === Step 4 ===
# Expanding Node: E
# Path so far: ['A', 'B', 'E']
# Cost so far (g): 5, Estimated total cost (f): 17
# Visited: frozenset({'A', 'E', 'B'})
# Unvisited cities: {'C', 'D'}
#
#   Neighbor: C
#     Edge cost: 5
#     g_new: 10
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 8
#       Nearest back to start: 9
#     h_new: 18, f_new: 28
#
#   Neighbor: D
#     Edge cost: 1
#     g_new: 6
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 8
#       Nearest back to start: 9
#     h_new: 18, f_new: 24
# Priority queue size: 10
#
# === Step 5 ===
# Expanding Node: D
# Path so far: ['A', 'B', 'D']
# Cost so far (g): 6, Estimated total cost (f): 18
# Visited: frozenset({'D', 'A', 'B'})
# Unvisited cities: {'C', 'E'}
#
#   Neighbor: C
#     Edge cost: 8
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 5
#       Nearest back to start: 3
#     h_new: 9, f_new: 23
#
#   Neighbor: E
#     Edge cost: 1
#     g_new: 7
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 5
#       Nearest back to start: 3
#     h_new: 9, f_new: 16
# Priority queue size: 11
#
# === Step 6 ===
# Expanding Node: E
# Path so far: ['A', 'B', 'D', 'E']
# Cost so far (g): 7, Estimated total cost (f): 16
# Visited: frozenset({'D', 'A', 'E', 'B'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 5
#     g_new: 12
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 14, f_new: 26
# Priority queue size: 11
#
# === Step 7 ===
# Expanding Node: B
# Path so far: ['A', 'E', 'B']
# Cost so far (g): 6, Estimated total cost (f): 19
# Visited: frozenset({'A', 'E', 'B'})
# Unvisited cities: {'C', 'D'}
#
#   Neighbor: C
#     Edge cost: 6
#     g_new: 12
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 8
#       Nearest back to start: 9
#     h_new: 21, f_new: 33
#
#   Neighbor: D
#     Edge cost: 4
#     g_new: 10
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 8
#       Nearest back to start: 9
#     h_new: 21, f_new: 31
# Priority queue size: 12
#
# === Step 8 ===
# Expanding Node: B
# Path so far: ['A', 'E', 'D', 'B']
# Cost so far (g): 8, Estimated total cost (f): 20
# Visited: frozenset({'B', 'A', 'E', 'D'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 6
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 15, f_new: 29
# Priority queue size: 12
#
# === Step 9 ===
# Expanding Node: C
# Path so far: ['A', 'B', 'C']
# Cost so far (g): 8, Estimated total cost (f): 20
# Visited: frozenset({'C', 'A', 'B'})
# Unvisited cities: {'E', 'D'}
#
#   Neighbor: D
#     Edge cost: 8
#     g_new: 16
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 1
#       Nearest back to start: 3
#     h_new: 9, f_new: 25
#
#   Neighbor: E
#     Edge cost: 5
#     g_new: 13
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 1
#       Nearest back to start: 3
#     h_new: 9, f_new: 22
# Priority queue size: 13
#
# === Step 10 ===
# Expanding Node: C
# Path so far: ['A', 'E', 'C']
# Cost so far (g): 8, Estimated total cost (f): 21
# Visited: frozenset({'C', 'A', 'E'})
# Unvisited cities: {'D', 'B'}
#
#   Neighbor: B
#     Edge cost: 6
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 12, f_new: 26
#
#   Neighbor: D
#     Edge cost: 8
#     g_new: 16
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 12, f_new: 28
# Priority queue size: 14
#
# === Step 11 ===
# Expanding Node: C
# Path so far: ['A', 'C']
# Cost so far (g): 9, Estimated total cost (f): 22
# Visited: frozenset({'C', 'A'})
# Unvisited cities: {'D', 'E', 'B'}
#
#   Neighbor: B
#     Edge cost: 6
#     g_new: 15
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 11, f_new: 26
#
#   Neighbor: D
#     Edge cost: 8
#     g_new: 17
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 11, f_new: 28
#
#   Neighbor: E
#     Edge cost: 5
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 11, f_new: 25
# Priority queue size: 16
#
# === Step 12 ===
# Expanding Node: E
# Path so far: ['A', 'B', 'C', 'E']
# Cost so far (g): 13, Estimated total cost (f): 22
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 1
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 11, f_new: 25
# Priority queue size: 16
#
# === Step 13 ===
# Expanding Node: D
# Path so far: ['A', 'D']
# Cost so far (g): 10, Estimated total cost (f): 23
# Visited: frozenset({'A', 'D'})
# Unvisited cities: {'C', 'E', 'B'}
#
#   Neighbor: B
#     Edge cost: 4
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 8
#       Nearest back to start: 2
#     h_new: 11, f_new: 25
#
#   Neighbor: C
#     Edge cost: 8
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 8
#       Nearest back to start: 2
#     h_new: 11, f_new: 29
#
#   Neighbor: E
#     Edge cost: 1
#     g_new: 11
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 8
#       Nearest back to start: 2
#     h_new: 11, f_new: 22
# Priority queue size: 18
#
# === Step 14 ===
# Expanding Node: E
# Path so far: ['A', 'D', 'E']
# Cost so far (g): 11, Estimated total cost (f): 22
# Visited: frozenset({'A', 'E', 'D'})
# Unvisited cities: {'C', 'B'}
#
#   Neighbor: B
#     Edge cost: 3
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 6
#       Nearest back to start: 2
#     h_new: 11, f_new: 25
#
#   Neighbor: C
#     Edge cost: 5
#     g_new: 16
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 6
#       Nearest back to start: 2
#     h_new: 11, f_new: 27
# Priority queue size: 19
#
# === Step 15 ===
# Expanding Node: C
# Path so far: ['A', 'B', 'D', 'C']
# Cost so far (g): 14, Estimated total cost (f): 23
# Visited: frozenset({'C', 'D', 'A', 'B'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 5
#     g_new: 19
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 8, f_new: 27
# Priority queue size: 19
#
# === Step 16 ===
# Expanding Node: D
# Path so far: ['A', 'B', 'E', 'D']
# Cost so far (g): 6, Estimated total cost (f): 24
# Visited: frozenset({'D', 'A', 'E', 'B'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 8
#     g_new: 14
#     Heuristic breakdown:
#       Nearest from current: 8
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 17, f_new: 31
# Priority queue size: 19
#
# === Step 17 ===
# Expanding Node: C
# Path so far: ['A', 'E', 'D', 'C']
# Cost so far (g): 12, Estimated total cost (f): 24
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 6
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 8, f_new: 26
# Priority queue size: 19
#
# === Step 18 ===
# Expanding Node: B
# Path so far: ['A', 'D', 'B']
# Cost so far (g): 14, Estimated total cost (f): 25
# Visited: frozenset({'B', 'A', 'D'})
# Unvisited cities: {'C', 'E'}
#
#   Neighbor: C
#     Edge cost: 6
#     g_new: 20
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 5
#       Nearest back to start: 3
#     h_new: 11, f_new: 31
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 17
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 5
#       Nearest back to start: 3
#     h_new: 11, f_new: 28
# Priority queue size: 20
#
# === Step 19 ===
# Expanding Node: B
# Path so far: ['A', 'D', 'E', 'B']
# Cost so far (g): 14, Estimated total cost (f): 25
# Visited: frozenset({'B', 'A', 'E', 'D'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 6
#     g_new: 20
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 15, f_new: 35
# Priority queue size: 20
#
# === Step 20 ===
# Expanding Node: D
# Path so far: ['A', 'B', 'C', 'E', 'D']
# Cost so far (g): 14, Estimated total cost (f): 25
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 24
#
# === Step 21 ===
# Expanding Node: E
# Path so far: ['A', 'C', 'E']
# Cost so far (g): 14, Estimated total cost (f): 25
# Visited: frozenset({'C', 'A', 'E'})
# Unvisited cities: {'D', 'B'}
#
#   Neighbor: B
#     Edge cost: 3
#     g_new: 17
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 7, f_new: 24
#
#   Neighbor: D
#     Edge cost: 1
#     g_new: 15
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 4
#       Nearest back to start: 2
#     h_new: 7, f_new: 22
# Priority queue size: 20
#
# === Step 22 ===
# Expanding Node: D
# Path so far: ['A', 'C', 'E', 'D']
# Cost so far (g): 15, Estimated total cost (f): 22
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 4
#     g_new: 19
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 6, f_new: 25
# Priority queue size: 20
#
# === Step 23 ===
# Expanding Node: B
# Path so far: ['A', 'C', 'E', 'B']
# Cost so far (g): 17, Estimated total cost (f): 24
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 4
#     g_new: 21
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 14, f_new: 35
# Priority queue size: 20
#
# === Step 24 ===
# Expanding Node: D
# Path so far: ['A', 'B', 'C', 'D']
# Cost so far (g): 16, Estimated total cost (f): 25
# Visited: frozenset({'C', 'D', 'A', 'B'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 1
#     g_new: 17
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 4, f_new: 21
# Priority queue size: 20
#
# === Step 25 ===
# Expanding Node: E
# Path so far: ['A', 'B', 'C', 'D', 'E']
# Cost so far (g): 17, Estimated total cost (f): 21
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 3, Total: 20
#
# === Step 26 ===
# Expanding Node: B
# Path so far: ['A', 'C', 'E', 'D', 'B']
# Cost so far (g): 19, Estimated total cost (f): 25
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 21
#
# === Step 27 ===
# Expanding Node: C
# Path so far: ['A', 'B', 'D', 'E', 'C']
# Cost so far (g): 12, Estimated total cost (f): 26
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 9, Total: 21
#
# === Step 28 ===
# Expanding Node: B
# Path so far: ['A', 'E', 'C', 'B']
# Cost so far (g): 14, Estimated total cost (f): 26
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 4
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 14, f_new: 32
# Priority queue size: 17
#
# === Step 29 ===
# Expanding Node: B
# Path so far: ['A', 'C', 'B']
# Cost so far (g): 15, Estimated total cost (f): 26
# Visited: frozenset({'C', 'A', 'B'})
# Unvisited cities: {'E', 'D'}
#
#   Neighbor: D
#     Edge cost: 4
#     g_new: 19
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 1
#       Nearest back to start: 3
#     h_new: 7, f_new: 26
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 1
#       Nearest back to start: 3
#     h_new: 7, f_new: 25
# Priority queue size: 18
#
# === Step 30 ===
# Expanding Node: E
# Path so far: ['A', 'C', 'B', 'E']
# Cost so far (g): 18, Estimated total cost (f): 25
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 1
#     g_new: 19
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 11, f_new: 30
# Priority queue size: 18
#
# === Step 31 ===
# Expanding Node: B
# Path so far: ['A', 'E', 'D', 'C', 'B']
# Cost so far (g): 18, Estimated total cost (f): 26
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 20
#
# === Step 32 ===
# Expanding Node: D
# Path so far: ['A', 'C', 'B', 'D']
# Cost so far (g): 19, Estimated total cost (f): 26
# Visited: frozenset({'C', 'D', 'A', 'B'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 1
#     g_new: 20
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 4, f_new: 24
# Priority queue size: 17
#
# === Step 33 ===
# Expanding Node: E
# Path so far: ['A', 'C', 'B', 'D', 'E']
# Cost so far (g): 20, Estimated total cost (f): 24
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 3, Total: 23
#
# === Step 34 ===
# Expanding Node: C
# Path so far: ['A', 'D', 'E', 'C']
# Cost so far (g): 16, Estimated total cost (f): 27
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 6
#     g_new: 22
#     Heuristic breakdown:
#       Nearest from current: 6
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 8, f_new: 30
# Priority queue size: 16
#
# === Step 35 ===
# Expanding Node: E
# Path so far: ['A', 'B', 'D', 'C', 'E']
# Cost so far (g): 19, Estimated total cost (f): 27
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 3, Total: 22
#
# === Step 36 ===
# Expanding Node: C
# Path so far: ['A', 'B', 'E', 'C']
# Cost so far (g): 10, Estimated total cost (f): 28
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 8
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 8
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 18, f_new: 36
# Priority queue size: 15
#
# === Step 37 ===
# Expanding Node: D
# Path so far: ['A', 'E', 'C', 'D']
# Cost so far (g): 16, Estimated total cost (f): 28
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 4
#     g_new: 20
#     Heuristic breakdown:
#       Nearest from current: 4
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 6, f_new: 26
# Priority queue size: 15
#
# === Step 38 ===
# Expanding Node: B
# Path so far: ['A', 'E', 'C', 'D', 'B']
# Cost so far (g): 20, Estimated total cost (f): 26
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 22
#
# === Step 39 ===
# Expanding Node: D
# Path so far: ['A', 'C', 'D']
# Cost so far (g): 17, Estimated total cost (f): 28
# Visited: frozenset({'C', 'A', 'D'})
# Unvisited cities: {'E', 'B'}
#
#   Neighbor: B
#     Edge cost: 4
#     g_new: 21
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 3
#       Nearest back to start: 2
#     h_new: 6, f_new: 27
#
#   Neighbor: E
#     Edge cost: 1
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 1
#       MST for unvisited: 3
#       Nearest back to start: 2
#     h_new: 6, f_new: 24
# Priority queue size: 15
#
# === Step 40 ===
# Expanding Node: E
# Path so far: ['A', 'C', 'D', 'E']
# Cost so far (g): 18, Estimated total cost (f): 24
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 3
#     g_new: 21
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 5, f_new: 26
# Priority queue size: 15
#
# === Step 41 ===
# Expanding Node: B
# Path so far: ['A', 'C', 'D', 'E', 'B']
# Cost so far (g): 21, Estimated total cost (f): 26
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 23
#
# === Step 42 ===
# Expanding Node: B
# Path so far: ['A', 'C', 'D', 'B']
# Cost so far (g): 21, Estimated total cost (f): 27
# Visited: frozenset({'C', 'B', 'A', 'D'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 24
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 6, f_new: 30
# Priority queue size: 14
#
# === Step 43 ===
# Expanding Node: E
# Path so far: ['A', 'D', 'B', 'E']
# Cost so far (g): 17, Estimated total cost (f): 28
# Visited: frozenset({'B', 'A', 'E', 'D'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 5
#     g_new: 22
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 14, f_new: 36
# Priority queue size: 14
#
# === Step 44 ===
# Expanding Node: C
# Path so far: ['A', 'E', 'D', 'B', 'C']
# Cost so far (g): 14, Estimated total cost (f): 29
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 9, Total: 23
#
# === Step 45 ===
# Expanding Node: C
# Path so far: ['A', 'D', 'C']
# Cost so far (g): 18, Estimated total cost (f): 29
# Visited: frozenset({'C', 'A', 'D'})
# Unvisited cities: {'E', 'B'}
#
#   Neighbor: B
#     Edge cost: 6
#     g_new: 24
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 3
#       Nearest back to start: 2
#     h_new: 10, f_new: 34
#
#   Neighbor: E
#     Edge cost: 5
#     g_new: 23
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 3
#       Nearest back to start: 2
#     h_new: 10, f_new: 33
# Priority queue size: 14
#
# === Step 46 ===
# Expanding Node: D
# Path so far: ['A', 'C', 'B', 'E', 'D']
# Cost so far (g): 19, Estimated total cost (f): 30
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 29
#
# === Step 47 ===
# Expanding Node: B
# Path so far: ['A', 'D', 'E', 'C', 'B']
# Cost so far (g): 22, Estimated total cost (f): 30
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 24
#
# === Step 48 ===
# Expanding Node: E
# Path so far: ['A', 'C', 'D', 'B', 'E']
# Cost so far (g): 24, Estimated total cost (f): 30
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 3, Total: 27
#
# === Step 49 ===
# Expanding Node: D
# Path so far: ['A', 'E', 'B', 'D']
# Cost so far (g): 10, Estimated total cost (f): 31
# Visited: frozenset({'D', 'A', 'E', 'B'})
# Unvisited cities: {'C'}
#
#   Neighbor: C
#     Edge cost: 8
#     g_new: 18
#     Heuristic breakdown:
#       Nearest from current: 8
#       MST for unvisited: 0
#       Nearest back to start: 9
#     h_new: 17, f_new: 35
# Priority queue size: 11
#
# === Step 50 ===
# Expanding Node: C
# Path so far: ['A', 'B', 'E', 'D', 'C']
# Cost so far (g): 14, Estimated total cost (f): 31
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 9, Total: 23
#
# === Step 51 ===
# Expanding Node: C
# Path so far: ['A', 'D', 'B', 'C']
# Cost so far (g): 20, Estimated total cost (f): 31
# Visited: frozenset({'C', 'B', 'A', 'D'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 5
#     g_new: 25
#     Heuristic breakdown:
#       Nearest from current: 5
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 8, f_new: 33
# Priority queue size: 10
#
# === Step 52 ===
# Expanding Node: D
# Path so far: ['A', 'E', 'C', 'B', 'D']
# Cost so far (g): 18, Estimated total cost (f): 32
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 28
#
# === Step 53 ===
# Expanding Node: C
# Path so far: ['A', 'E', 'B', 'C']
# Cost so far (g): 12, Estimated total cost (f): 33
# Visited: frozenset({'C', 'A', 'E', 'B'})
# Unvisited cities: {'D'}
#
#   Neighbor: D
#     Edge cost: 8
#     g_new: 20
#     Heuristic breakdown:
#       Nearest from current: 8
#       MST for unvisited: 0
#       Nearest back to start: 10
#     h_new: 18, f_new: 38
# Priority queue size: 9
#
# === Step 54 ===
# Expanding Node: E
# Path so far: ['A', 'D', 'C', 'E']
# Cost so far (g): 23, Estimated total cost (f): 33
# Visited: frozenset({'C', 'A', 'E', 'D'})
# Unvisited cities: {'B'}
#
#   Neighbor: B
#     Edge cost: 3
#     g_new: 26
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 0
#       Nearest back to start: 2
#     h_new: 5, f_new: 31
# Priority queue size: 9
#
# === Step 55 ===
# Expanding Node: B
# Path so far: ['A', 'D', 'C', 'E', 'B']
# Cost so far (g): 26, Estimated total cost (f): 31
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 2, Total: 28
#
# === Step 56 ===
# Expanding Node: E
# Path so far: ['A', 'D', 'B', 'C', 'E']
# Cost so far (g): 25, Estimated total cost (f): 33
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 3, Total: 28
#
# === Step 57 ===
# Expanding Node: B
# Path so far: ['A', 'D', 'C', 'B']
# Cost so far (g): 24, Estimated total cost (f): 34
# Visited: frozenset({'C', 'B', 'A', 'D'})
# Unvisited cities: {'E'}
#
#   Neighbor: E
#     Edge cost: 3
#     g_new: 27
#     Heuristic breakdown:
#       Nearest from current: 3
#       MST for unvisited: 0
#       Nearest back to start: 3
#     h_new: 6, f_new: 33
# Priority queue size: 7
#
# === Step 58 ===
# Expanding Node: E
# Path so far: ['A', 'D', 'C', 'B', 'E']
# Cost so far (g): 27, Estimated total cost (f): 33
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 3, Total: 30
#
# === Step 59 ===
# Expanding Node: C
# Path so far: ['A', 'E', 'B', 'D', 'C']
# Cost so far (g): 18, Estimated total cost (f): 35
# Visited: frozenset({'B', 'A', 'E', 'D', 'C'})
# Reached goal! Returning to start costs 9, Total: 27
#
# === Step 60 ===
# Expanding Node: C
# Path so far: ['A', 'D', 'E', 'B', 'C']
# Cost so far (g): 20, Estimated total cost (f): 35
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 9, Total: 29
#
# === Step 61 ===
# Expanding Node: D
# Path so far: ['A', 'C', 'E', 'B', 'D']
# Cost so far (g): 21, Estimated total cost (f): 35
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 31
#
# === Step 62 ===
# Expanding Node: D
# Path so far: ['A', 'B', 'E', 'C', 'D']
# Cost so far (g): 18, Estimated total cost (f): 36
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 28
#
# === Step 63 ===
# Expanding Node: C
# Path so far: ['A', 'D', 'B', 'E', 'C']
# Cost so far (g): 22, Estimated total cost (f): 36
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 9, Total: 31
#
# === Step 64 ===
# Expanding Node: D
# Path so far: ['A', 'E', 'B', 'C', 'D']
# Cost so far (g): 20, Estimated total cost (f): 38
# Visited: frozenset({'A', 'D', 'E', 'B', 'C'})
# Reached goal! Returning to start costs 10, Total: 30
# === Search Complete ===
# Best Path: ['A', 'B', 'C', 'D', 'E', 'A']
# Minimum Cost: 20

# %% [markdown]
# ### Full code for TSP problem (no explanation)

# %%
import heapq
from math import inf

def mst_cost(nodes, graph):
    """Compute MST cost using Prim's algorithm for given nodes."""
    if not nodes:
        return 0
    visited = set()
    total_cost = 0
    start = next(iter(nodes))
    visited.add(start)

    while len(visited) < len(nodes):
        min_edge = inf
        next_node = None
        for u in visited:
            for v, cost in graph[u]:
                if v in nodes and v not in visited and cost < min_edge:
                    min_edge = cost
                    next_node = v
        if next_node:
            visited.add(next_node)
            total_cost += min_edge
        else:
            break
    return total_cost

def tsp_a_star(graph, start):
    cities = list(graph.keys())
    start_city = start

    # Priority Queue: (f, g, current_city, visited_tuple, path)
    pq = []
    heapq.heappush(pq, (0, 0, start_city, frozenset([start_city]), [start_city]))

    best_cost = inf
    best_path = None

    while pq:
        f, g, current, visited, path = heapq.heappop(pq)

        # Goal: visited all cities and return to start
        if len(visited) == len(cities):
            return_cost = next(cost for v, cost in graph[current] if v == start_city)
            total_cost = g + return_cost
            if total_cost < best_cost:
                best_cost = total_cost
                best_path = path + [start_city]
            continue

        # Generate successors
        unvisited = set(cities) - visited
        for neighbor, cost in graph[current]:
            if neighbor not in visited:
                g_new = g + cost

                # Heuristic calculation:
                nearest_unvisited_from_current = min(
                    (c for c in (cost for v, cost in graph[current] if v in unvisited)), default=0
                )
                mst_for_unvisited = mst_cost(unvisited, graph)
                nearest_to_start = min(
                    (cost for v in unvisited for nv, cost in graph[v] if nv == start_city),
                    default=0
                )

                h_new = nearest_unvisited_from_current + mst_for_unvisited + nearest_to_start
                f_new = g_new + h_new

                new_visited = visited | {neighbor}
                heapq.heappush(pq, (f_new, g_new, neighbor, frozenset(new_visited), path + [neighbor]))

    return best_path, best_cost

# %%
graph = {
    'A': [('B', 2), ('C', 9), ('D', 10), ('E', 3)],
    'B': [('A', 2), ('C', 6), ('D', 4), ('E', 3)],
    'C': [('A', 9), ('B', 6), ('D', 8), ('E', 5)],
    'D': [('A', 10), ('B', 4), ('C', 8), ('E', 1)],
    'E': [('A', 3), ('B', 3), ('C', 5), ('D', 1)],
}

path, cost = tsp_a_star(graph, 'A')
print("Best Path:", path)
print("Minimum Cost:", cost)
# Out:
# Best Path: ['A', 'B', 'C', 'D', 'E', 'A']
# Minimum Cost: 20
